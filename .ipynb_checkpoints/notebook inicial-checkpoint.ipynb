# %% [markdown]
# # Fruits fresh and rotten for classification

# %% [markdown]
# 1. introducció
#
# Utiltzare la llibreria Keras de tensorflow per el tractament de les dades ja que tinc carpetes amb imatges girades en comptes de un csv com estaba habituat. He treballat amb aquesta llibreria a la assignatura de visio per computador l'any passat y pel que he vist Tensorflow no esta Suportat en la versió de python 3.11 per lo que he tingut que pasar a 3.10 per si voleu executar el codi vosaltres.

# %%
from src import funcionshow
from src import librerias
import sys
TRAIN_PATH = '/data/dataset/train/'
TEST_PATH = "/data/test/"

# %%
labels,imlabels,imnames,numim,numlab=librerias.crear_labels('/../data/dataset/train/')

#data augmentation
train=ImageDataGenerator(rescale=1./255, validation_split = 0.1)
test=ImageDataGenerator(rescale=1/255.0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14704\1504080189.py in <module>
# ----> 1 labels,imlabels,imnames,numim,numlab=librerias.crear_labels('/../data/dataset/train/')
#       2
#       3 #data augmentation
#       4 train=ImageDataGenerator(rescale=1./255, validation_split = 0.1)
#       5 test=ImageDataGenerator(rescale=1/255.0)
#
# ~\Downloads\kaggle\src\librerias.py in crear_labels(TRAIN_PATH)
#      30     imnames = []
#      31     imlabels = []
# ---> 32     for class_ in os.listdir(TRAIN_PATH):
#      33         labels.append(class_)
#      34         for im in os.listdir(TRAIN_PATH+str(class_)):
#
# FileNotFoundError: [WinError 3] El sistema no puede encontrar la ruta especificada: '/../data/dataset/train/'

# %%
train_dataset = train.flow_from_directory(batch_size=BATCH_SIZE,directory=TEST_PATH,shuffle=True,classes=labels,target_size=IMG_SHAPE, subset="training",class_mode='categorical')
val_dataset = train.flow_from_directory(batch_size=BATCH_SIZE,directory=TEST_PATH,shuffle=True,classes=labels,target_size=IMG_SHAPE, subset="validation",class_mode='categorical')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1756\1414354367.py in <module>
# ----> 1 train_dataset = train.flow_from_directory(batch_size=BATCH_SIZE,directory=TEST_PATH,shuffle=True,classes=labels,target_size=IMG_SHAPE, subset="training",class_mode='categorical')
#       2 val_dataset = train.flow_from_directory(batch_size=BATCH_SIZE,directory=TEST_PATH,shuffle=True,classes=labels,target_size=IMG_SHAPE, subset="validation",class_mode='categorical')
#
# NameError: name 'train' is not defined

# %%
funcionshow.imprimirimg(train_dataset,labels,4,4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5976\293116293.py in <module>
# ----> 1 funcionshow.imprimirimg(train_dataset,labels,4,4)
#
# NameError: name 'funcionshow' is not defined

# %% [markdown]
# Un cop hem llegit les dades veiem que en train_dataset[X][0] tenim els valors de les imatges per tal de ser impresas amb plt, en train_dataset[X][1] un array que ens indica a quina clase / carpeta pertany la fruita en questió provare les dades amb la carpeta test per tal de prevenir un cas de overflow ja que hi ha 10000 imatges en train y 2500 nomes en test. La variable X arriba fins al valor de dividir el numero de imatges/BATCH_SIZE en la funció ImageDataGenerator que ens realitza un Data augmentation a les meves dades.

# %% [markdown]
# Les diferents variables que tenim son la categoria a la que pertany la nostre imatge que sera 1 si pertany i si no pertany en aquella columna hi haura un valor 0, el nostre objectius es detectar si una fruita esta en bones condicions o no per molt que hi hagi una foto amb la fruita girada o no.

# %% [markdown]
# # 2. aplicar models

# %% [markdown]
# CROSSVALIDATION

# %%
# Define the model architecture , (64, 240, 240, 3)shape dataset

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(240,240,3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(NUM_LABELS, activation='softmax'))

# %%
# Define the K-fold Cross Validator
k_folds = 6
kfold = KFold(n_splits=k_folds, shuffle=True)

# K-fold Cross Validation model evaluation
fold_no = 1
print(kfold)
# Out:
# KFold(n_splits=6, random_state=None, shuffle=True)

# %% [markdown]
# per poder aplicar un K-Fold Crossvalidation vaig pensar en dividir el train i realitzar un .flow_from_directory() a cada iteracio a partir del train incial que ja te el ImageDataGenerator aplicat.

# %%
#necesitem valors numerics per tal de poder aplicar flow
aux1 = []
aux2 = []
for i,im in enumerate(imnames):
    image = cv2.imread(im)
    aux1.append(np.array(image.flatten(), dtype=object))
    aux2.append(np.where(labels==imlabels[i])[0][0])
X = np.array(aux1, dtype=object)
y = np.array(aux2)
# Out:
# [array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object) ...
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([100, 125, 178, ..., 107, 85, 91], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)]

# %%
print(len(X))
# Out:
# 2698

# %%
acc = []
i =0
for train_index, val_index in kfold.split(X):
    
    
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    print("=========================================")
    print("====== K Fold Validation step => %d/%d =======" % (fold_no,k_folds))
    print("=========================================")
    
    print(X_val)
    
    val_gen = train.flow(x=X_val.flatten(), y=y_val,batch_size=BATCH_SIZE)
    train_gen = train.flow(x=X_train, y=y_train, batch_size=BATCH_SIZE) #tienen que ser valores numericos
    
    
    model.fit(generator=train_gen, validation_data=val_gen)
    
    _,accuracy=model.evaluate(val_data, verbose=0)
    fold_no = fold_no + 1
    acc.append(accuracy)
    
print("Average accuracy:", sum(accuracies) / len(accuracies))
# Out:
# =========================================
# ====== K Fold Validation step => 1/6 =======
# =========================================
# [array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([65, 185, 128, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 240, 240, 240], dtype=object)
#  array([255, 255, 255, ..., 153, 209, 201], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([242, 242, 242, ..., 239, 239, 239], dtype=object)
#  array([251, 255, 254, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 251, 250, 251], dtype=object)
#  array([0, 0, 0, ..., 234, 232, 235], dtype=object)
#  array([0, 0, 0, ..., 254, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([241, 241, 241, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([247, 247, 247, ..., 252, 249, 251], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 137, 171, 192], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([247, 247, 247, ..., 249, 249, 249], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([103, 150, 227, ..., 145, 191, 243], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([34, 119, 52, ..., 49, 111, 218], dtype=object)
#  array([255, 254, 253, ..., 255, 255, 247], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 35, 118, 65], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 237, 231, 238], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 254], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([240, 240, 240, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 246, 249, 253], dtype=object)
#  array([255, 255, 255, ..., 253, 255, 255], dtype=object)
#  array([207, 216, 220, ..., 217, 232, 240], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([206, 201, 195, ..., 231, 228, 225], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 255, 253, 251], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 246, 242, 241], dtype=object)
#  array([0, 0, 0, ..., 249, 250, 249], dtype=object)
#  array([0, 0, 0, ..., 240, 229, 230], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 246, 250, 252], dtype=object)
#  array([255, 255, 255, ..., 254, 254, 254], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([245, 240, 241, ..., 221, 218, 219], dtype=object)
#  array([255, 255, 255, ..., 252, 252, 252], dtype=object)
#  array([216, 208, 213, ..., 160, 178, 192], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 242, 245, 248], dtype=object)
#  array([177, 178, 182, ..., 122, 112, 117], dtype=object)
#  array([193, 192, 195, ..., 204, 203, 205], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 253, 254, ..., 255, 253, 254], dtype=object)
#  array([183, 181, 178, ..., 175, 173, 171], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([218, 196, 193, ..., 255, 255, 255], dtype=object)
#  array([247, 223, 205, ..., 254, 244, 232], dtype=object)
#  array([136, 188, 210, ..., 137, 184, 200], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 242, 242, 242], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([136, 161, 178, ..., 163, 169, 184], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([195, 235, 248, ..., 226, 248, 253], dtype=object)
#  array([255, 255, 255, ..., 228, 231, 234], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 252, 244, 240], dtype=object)
#  array([0, 0, 0, ..., 165, 219, 235], dtype=object)
#  array([0, 0, 0, ..., 54, 55, 53], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([247, 248, 245, ..., 255, 255, 255], dtype=object)
#  array([252, 252, 252, ..., 249, 249, 249], dtype=object)
#  array([204, 204, 204, ..., 201, 199, 199], dtype=object)
#  array([254, 252, 250, ..., 254, 251, 242], dtype=object)
#  array([204, 205, 208, ..., 133, 165, 179], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([75, 149, 194, ..., 57, 53, 46], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([187, 190, 193, ..., 176, 180, 185], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([254, 254, 253, ..., 255, 255, 255], dtype=object)
#  array([247, 236, 232, ..., 253, 249, 244], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([110, 107, 104, ..., 33, 32, 33], dtype=object)
#  array([168, 168, 168, ..., 197, 193, 192], dtype=object)
#  array([232, 229, 230, ..., 218, 220, 222], dtype=object)
#  array([117, 133, 155, ..., 140, 153, 170], dtype=object)
#  array([7, 16, 90, ..., 255, 254, 253], dtype=object)
#  array([188, 215, 246, ..., 178, 198, 231], dtype=object)
#  array([255, 254, 254, ..., 255, 255, 255], dtype=object)
#  array([211, 211, 211, ..., 221, 221, 221], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([169, 176, 200, ..., 74, 106, 160], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 0, 0, 0], dtype=object)
#  array([0, 0, 0, ..., 97, 109, 127], dtype=object)
#  array([0, 0, 0, ..., 255, 255, 255], dtype=object)
#  array([0, 0, 0, ..., 205, 204, 207], dtype=object)
#  array([0, 0, 0, ..., 252, 248, 253], dtype=object)
#  array([0, 0, 0, ..., 245, 234, 224], dtype=object)
#  array([253, 249, 248, ..., 254, 246, 245], dtype=object)
#  array([233, 233, 233, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)
#  array([226, 226, 226, ..., 255, 255, 255], dtype=object)
#  array([227, 224, 225, ..., 226, 229, 228], dtype=object)
#  array([255, 255, 255, ..., 255, 255, 255], dtype=object)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5976\3171308997.py in <module>
#      12     print(X_val)
#      13
# ---> 14     val_gen = train.flow(x=X_val.flatten(), y=y_val,batch_size=BATCH_SIZE)
#      15     train_gen = train.flow(x=X_train, y=y_train, batch_size=BATCH_SIZE) #tienen que ser valores numericos
#      16
#
# ~\anaconda3\lib\site-packages\keras\preprocessing\image.py in flow(self, x, y, batch_size, shuffle, sample_weight, seed, save_to_dir, save_prefix, save_format, ignore_class_split, subset)
#    1545
#    1546         """
# -> 1547         return NumpyArrayIterator(
#    1548             x,
#    1549             y,
#
# ~\anaconda3\lib\site-packages\keras\preprocessing\image.py in __init__(self, x, y, image_data_generator, batch_size, shuffle, sample_weight, seed, data_format, save_to_dir, save_prefix, save_format, subset, ignore_class_split, dtype)
#     753                     y = y[split_idx:]
#     754
# --> 755         self.x = np.asarray(x, dtype=self.dtype)
#     756         self.x_misc = x_misc
#     757         if self.x.ndim != 4:
#
# ValueError: setting an array element with a sequence.

# %%
print(cv2.imread(imnames[0]).flatten())
# Out:
# [0 0 0 ... 0 0 0]
